# %% [markdown]
# <a href="https://colab.research.google.com/github/shakirullah-rgb/2nd_python_assig/blob/main/MLproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drugconcentration.csv")
print(df.head())
# Out:
#    serial  Subject  time  conc   dose  interval  Age  Height  Weight  \
# 0       1        1   0.0   NaN  249.0       NaN   60      69     106
# 1       2        1   3.0   NaN  249.0       NaN   60      69     106
# 2       3        1   6.0   NaN  249.0       NaN   60      69     106
# 3       4        1  16.0   NaN  201.0       NaN   60      69     106
# 4       5        1  24.0   NaN  201.0       NaN   60      69     106
#
#         Race Smoke  Ethanol     Heart Creatinine  glyco
# 0  Caucasian    no  current  Moderate      >= 50   0.41
# 1  Caucasian    no  current  Moderate      >= 50   0.41
# 2  Caucasian    no  current  Moderate      >= 50   0.41
# 3  Caucasian    no  current  Moderate      >= 50   0.41
# 4  Caucasian    no  current  Moderate      >= 50   0.41

# %%
# data information:

print("Dataset shape")
print(df.shape)
print("\n Culumn names")
print(df.columns.tolist())
print("\n data types")
print(df.dtypes)
print("\n missing values")
print(df.isnull().sum())
# Out:
# Dataset shape
# (1471, 15)
#
#  Culumn names
# ['serial', 'Subject', 'time', 'conc', 'dose', 'interval', 'Age', 'Height', 'Weight', 'Race', 'Smoke', 'Ethanol', 'Heart', 'Creatinine', 'glyco']
#
#  data types
# serial          int64
# Subject         int64
# time          float64
# conc          float64
# dose          float64
# interval      float64
# Age             int64
# Height          int64
# Weight          int64
# Race           object
# Smoke          object
# Ethanol        object
# Heart          object
# Creatinine     object
# glyco         float64
# dtype: object
#
#  missing values
# serial           0
# Subject          0
# time             0
# conc          1110
# dose           443
# interval      1222
# Age              0
# Height           0
# Weight           0
# Race             0
# Smoke            0
# Ethanol          0
# Heart            0
# Creatinine       0
# glyco            0
# dtype: int64
